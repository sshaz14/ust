# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings. filterwarnings('ignore')

# %% [markdown]
# 1.	Read a file constitution.txt. Create a dictionary with an entry for each letter in the alphabet. The keys are letters, and the values will be the counts of the number of times a letter has viewed. Go through each character in `data`, skipping characters that aren't letters. For every letter, increment the count stored in `letter_counts` for that letter. Create a bar chart for the letter frequencies.

# %%
file = open('constitution.txt', 'r')
data = file.read()
b = list(list(map(lambda x: x.lower(), list(data.split()))))
#print(b)
i=0
'''
for letter in letters[i]:
    print(letter)
    i+=1
'''   
d={'a':0,'b':0,'c':0,'d':0,'e':0,'f':0,'g':0,'h':0,'i':0,'j':0,'k':0,'l':0,'m':0,'n':0,'o':0,'p':0,'q':0,'r':0,'s':0,'t':0,'u':0,'v':0,'w':0,'x':0,'y':0,'z':0}
#d = dict()
for c in b[i]:#range(len(b)):
    if c in d:
        d[c] = 1
    else:
        d[c] = d[c] + 1
    i+=1 
print(d)
'''
words = letter.split()
for word in words:
    print(word)
 '''
# Out:
# {'a': 0, 'b': 0, 'c': 0, 'd': 0, 'e': 1, 'f': 0, 'g': 0, 'h': 0, 'i': 0, 'j': 0, 'k': 0, 'l': 0, 'm': 0, 'n': 0, 'o': 0, 'p': 0, 'q': 0, 'r': 0, 's': 0, 't': 0, 'u': 0, 'v': 0, 'w': 1, 'x': 0, 'y': 0, 'z': 0}
# '\nwords = letter.split()\nfor word in words:\n    print(word)\n '

# %%
word = 'brontosaurus'
d = dict()
for c in word:
    if c not in d:
        d[c] = 1
    else:
        d[c] = d[c] + 1
print(d)
# Out:
# {'b': 1, 'r': 2, 'o': 2, 'n': 1, 't': 1, 's': 2, 'a': 1, 'u': 2}

# %%
 for word in words:
        if word in frequency:
            frequency[word] += 1
        else:
            frequency[word] = 1

# %%
keys={'a':0,'b':0,'c':0,'d':0,'e':0,'f':0,'g':0,'h':0,'i':0,'j':0,'k':0,'l':0,'m':0,'n':0,'o':0,'p':0,'q':0,'r':0,'s':0,'t':0,'u':0,'v':0,'w':0,'x':0,'y':0,'z':0}

# %%
letter_counts=0
for char in range(len(b)):
    if char.isalpha():
        keys[char] += 1
        letter_counts+=1
        print(keys, letter_counts, keys[char], letter)
    else:
        pass
print('Letters', keys)
#print('Digits', dict1['Digits'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28772/3722422851.py in <module>
#       1 letter_counts=0
#       2 for char in range(len(b)):
# ----> 3     if char.isalpha():
#       4         keys[char] += 1
#       5         letter_counts+=1
#
# AttributeError: 'int' object has no attribute 'isalpha'

# %%
def wordcount(string):
    frequency=dict()
    keys = string.split()
    
    for key in keys:
        if isLetter() in frequency:
            frequency[letter]+=1
        else:
            frequency[word]=1
    return frequency

pd.Series(wordcount(sentence)).plot.bar(figsize = (25,30), color = 'plum')
# Out:
# <AxesSubplot:>

# %% [markdown]
# 2.	Create a Python program to find and remove duplicate files from a given folder location or subfolder location passed as input.
#
# a.	Find & Drop duplicate files by names.
# b.	Find & Drop duplicate files by content. (Hint: Use hashlib)

# %% [markdown]
# 3.	View and analyse the dataset using Pandas.
# a.	Read data from csv file Federal Aviation Authority (FAA) Dataset
# b.	View content of the data
# c.	View the dataset shape
# d.	Show all the columns present in the dataset
# e.	Extract the following attributes from the dataset:
# 'ACFT_MAKE_NAME', 'LOC_STATE_NAME', 'ACFT_MODEL_NAME', 'RMK_TEXT'1 'FLT_PHASE', 'EVENT_TYPE_DESC', 'FATAL_FLAG'
# f.	Show missing values count for each column.
# g.	Clean the dataset and replace the fatal flag NaN with “No”
# h.	Verify if the missing values are replaced.
# i.	Remove all the observations where aircraft names (ACFT_MAKE_NAME) are not available
# j.	Find the aircraft types and their occurrences in the dataset
# k.	Display the observations where fatal flag is “Yes”.
# l.	Show the accidents with fatality.

# %% [markdown]
# a.	Read data from csv file Federal Aviation Authority (FAA) Dataset

# %%
# import pandas library
import pandas as pd

# %%
# load csv file
faa = pd.read_csv('faa_ai_prelim.csv')

# %% [markdown]
# b.	View content of the data

# %%
display(faa)
# Out:
#    UPDATED ENTRY_DATE EVENT_LCL_DATE EVENT_LCL_TIME LOC_CITY_NAME  \
# 0       No  19-FEB-16      19-FEB-16      00:45:00Z    MARSHVILLE
# 1       No  19-FEB-16      18-FEB-16      23:55:00Z     TAVERNIER
# 2       No  19-FEB-16      18-FEB-16      22:14:00Z       TRENTON
# 3       No  19-FEB-16      18-FEB-16      17:10:00Z     ASHEVILLE
# 4       No  19-FEB-16      18-FEB-16      00:26:00Z     TALKEETNA
# ..     ...        ...            ...            ...           ...
# 78      No  08-FEB-16      31-DEC-15      17:00:00Z   SAN ANTONIO
# 79      No  08-FEB-16      05-FEB-16      11:17:00Z      MARICOPA
# 80      No  08-FEB-16      05-FEB-16      23:02:00Z     SAN PEDRO
# 81      No  08-FEB-16      05-FEB-16      23:02:00Z     SAN PEDRO
# 82     Yes  02-FEB-16      02-FEB-16      01:52:00Z        MOBILE
#
#     LOC_STATE_NAME LOC_CNTRY_NAME  \
# 0   North Carolina            NaN
# 1          Florida            NaN
# 2       New Jersey            NaN
# 3   North Carolina            NaN
# 4           Alaska            NaN
# ..             ...            ...
# 78           Texas            NaN
# 79         Arizona            NaN
# 80      California            NaN
# 81      California            NaN
# 82         Alabama            NaN
#
#                                              RMK_TEXT EVENT_TYPE_DESC  \
# 0   AIRCRAFT CRASHED INTO TREES, THE 1 PERSON ON B...        Accident
# 1   AIRCRAFT ON LANDING WENT OFF THE END OF THE RU...        Incident
# 2   AIRCRAFT ON FINAL SUSTAINED A BIRD STRIKE, LAN...        Incident
# 3   AIRCRAFT ON LANDING, GEAR COLLAPSED, ASHEVILLE...        Incident
# 4   AIRCRAFT ON LANDING, NOSE GEAR COLLAPSED, TALK...        Incident
# ..                                                ...             ...
# 78  AIRCRAFT ON LANDING, GROUND LOOPED, BULVERDE A...        Accident
# 79  AIRCRAFT CRASHED UNDER UNKNOWN CIRCUMSTANCES, ...        Accident
# 80  N9872R, BEECH M35 AIRCRAFT, AND N5057G, BELLAN...        Accident
# 81  N9872R, BEECH M35 AIRCRAFT, AND N5057G, BELLAN...        Accident
# 82  N784CP AIRCRAFT CRASHED INTO A WOODED AREA NEA...        Accident
#
#                    FSDO_DESC  ... PAX_INJ_NONE PAX_INJ_MINOR PAX_INJ_SERIOUS  \
# 0      FAA Charlotte FSDO-68  ...          NaN           NaN             NaN
# 1          FAA Miami FSDO-19  ...          NaN           NaN             NaN
# 2   FAA Philadelphia FSDO-17  ...          NaN           NaN             NaN
# 3      FAA Charlotte FSDO-68  ...          NaN           NaN             NaN
# 4      FAA Anchorage FSDO-03  ...          NaN           1.0             NaN
# ..                       ...  ...          ...           ...             ...
# 78   FAA San Antonio FSDO-17  ...          NaN           NaN             NaN
# 79    FAA Scottsdale FSDO-07  ...          NaN           NaN             NaN
# 80    FAA Long Beach FSDO-05  ...          NaN           NaN             NaN
# 81    FAA Long Beach FSDO-05  ...          NaN           NaN             NaN
# 82    FAA Birmingham FSDO-09  ...          NaN           NaN             NaN
#
#    PAX_INJ_FATAL PAX_INJ_UNK  GRND_INJ_NONE GRND_INJ_MINOR GRND_INJ_SERIOUS  \
# 0            NaN         NaN            NaN            NaN              NaN
# 1            NaN         NaN            NaN            NaN              NaN
# 2            NaN         NaN            NaN            NaN              NaN
# 3            NaN         NaN            NaN            NaN              NaN
# 4            NaN         NaN            NaN            NaN              NaN
# ..           ...         ...            ...            ...              ...
# 78           NaN         NaN            NaN            NaN              NaN
# 79           NaN         NaN            NaN            NaN              NaN
# 80           NaN         NaN            NaN            NaN              NaN
# 81           NaN         NaN            NaN            NaN              NaN
# 82           NaN         NaN            NaN            NaN              NaN
#
#    GRND_INJ_FATAL  GRND_INJ_UNK
# 0             NaN           NaN
# 1             NaN           NaN
# 2             NaN           NaN
# 3             NaN           NaN
# 4             NaN           NaN
# ..            ...           ...
# 78            NaN           NaN
# 79            NaN           NaN
# 80            NaN           NaN
# 81            NaN           NaN
# 82            NaN           NaN
#
# [83 rows x 42 columns]

# %% [markdown]
# c.	View the dataset shape

# %%
faa.shape
# Out:
# (83, 42)

# %% [markdown]
# d.	Show all the columns present in the dataset

# %%
faa.columns
# Out:
# Index(['UPDATED', 'ENTRY_DATE', 'EVENT_LCL_DATE', 'EVENT_LCL_TIME',
#        'LOC_CITY_NAME', 'LOC_STATE_NAME', 'LOC_CNTRY_NAME', 'RMK_TEXT',
#        'EVENT_TYPE_DESC', 'FSDO_DESC', 'REGIST_NBR', 'FLT_NBR', 'ACFT_OPRTR',
#        'ACFT_MAKE_NAME', 'ACFT_MODEL_NAME', 'ACFT_MISSING_FLAG',
#        'ACFT_DMG_DESC', 'FLT_ACTIVITY', 'FLT_PHASE', 'FAR_PART', 'MAX_INJ_LVL',
#        'FATAL_FLAG', 'FLT_CRW_INJ_NONE', 'FLT_CRW_INJ_MINOR',
#        'FLT_CRW_INJ_SERIOUS', 'FLT_CRW_INJ_FATAL', 'FLT_CRW_INJ_UNK',
#        'CBN_CRW_INJ_NONE', 'CBN_CRW_INJ_MINOR', 'CBN_CRW_INJ_SERIOUS',
#        'CBN_CRW_INJ_FATAL', 'CBN_CRW_INJ_UNK', 'PAX_INJ_NONE', 'PAX_INJ_MINOR',
#        'PAX_INJ_SERIOUS', 'PAX_INJ_FATAL', 'PAX_INJ_UNK', 'GRND_INJ_NONE',
#        'GRND_INJ_MINOR', 'GRND_INJ_SERIOUS', 'GRND_INJ_FATAL', 'GRND_INJ_UNK'],
#       dtype='object')

# %% [markdown]
# e.	Extract the following attributes from the dataset:
# 'ACFT_MAKE_NAME', 'LOC_STATE_NAME', 'ACFT_MODEL_NAME', 'RMK_TEXT'1 'FLT_PHASE', 'EVENT_TYPE_DESC', 'FATAL_FLAG'

# %%
faa[['ACFT_MAKE_NAME', 'LOC_STATE_NAME', 'ACFT_MODEL_NAME', 'RMK_TEXT', 'FLT_PHASE', 'EVENT_TYPE_DESC', 'FATAL_FLAG']]
# Out:
#     ACFT_MAKE_NAME  LOC_STATE_NAME ACFT_MODEL_NAME  \
# 0            BEECH  North Carolina              36
# 1             VANS         Florida             RV7
# 2           CESSNA      New Jersey             172
# 3          LANCAIR  North Carolina             235
# 4           CESSNA          Alaska             172
# ..             ...             ...             ...
# 78         AERONCA           Texas            O58B
# 79  NORTH AMERICAN         Arizona             F51
# 80        CHAMPION      California           8KCAB
# 81           BEECH      California              35
# 82          CESSNA         Alabama             182
#
#                                              RMK_TEXT       FLT_PHASE  \
# 0   AIRCRAFT CRASHED INTO TREES, THE 1 PERSON ON B...   UNKNOWN (UNK)
# 1   AIRCRAFT ON LANDING WENT OFF THE END OF THE RU...   LANDING (LDG)
# 2   AIRCRAFT ON FINAL SUSTAINED A BIRD STRIKE, LAN...  APPROACH (APR)
# 3   AIRCRAFT ON LANDING, GEAR COLLAPSED, ASHEVILLE...   LANDING (LDG)
# 4   AIRCRAFT ON LANDING, NOSE GEAR COLLAPSED, TALK...   LANDING (LDG)
# ..                                                ...             ...
# 78  AIRCRAFT ON LANDING, GROUND LOOPED, BULVERDE A...   LANDING (LDG)
# 79  AIRCRAFT CRASHED UNDER UNKNOWN CIRCUMSTANCES, ...   UNKNOWN (UNK)
# 80  N9872R, BEECH M35 AIRCRAFT, AND N5057G, BELLAN...   UNKNOWN (UNK)
# 81  N9872R, BEECH M35 AIRCRAFT, AND N5057G, BELLAN...   UNKNOWN (UNK)
# 82  N784CP AIRCRAFT CRASHED INTO A WOODED AREA NEA...   UNKNOWN (UNK)
#
#    EVENT_TYPE_DESC FATAL_FLAG
# 0         Accident        Yes
# 1         Incident        NaN
# 2         Incident        NaN
# 3         Incident        NaN
# 4         Incident        NaN
# ..             ...        ...
# 78        Accident        NaN
# 79        Accident        Yes
# 80        Accident        Yes
# 81        Accident        Yes
# 82        Accident        Yes
#
# [83 rows x 7 columns]

# %% [markdown]
# f.	Show missing values count for each column.

# %%
faa.isnull().sum()
# Out:
# UPDATED                 0
# ENTRY_DATE              0
# EVENT_LCL_DATE          0
# EVENT_LCL_TIME          0
# LOC_CITY_NAME           0
# LOC_STATE_NAME          0
# LOC_CNTRY_NAME         81
# RMK_TEXT                0
# EVENT_TYPE_DESC         0
# FSDO_DESC               2
# REGIST_NBR              0
# FLT_NBR                77
# ACFT_OPRTR             76
# ACFT_MAKE_NAME          5
# ACFT_MODEL_NAME         4
# ACFT_MISSING_FLAG      83
# ACFT_DMG_DESC           1
# FLT_ACTIVITY           70
# FLT_PHASE               1
# FAR_PART               82
# MAX_INJ_LVL             3
# FATAL_FLAG             75
# FLT_CRW_INJ_NONE       19
# FLT_CRW_INJ_MINOR      77
# FLT_CRW_INJ_SERIOUS    82
# FLT_CRW_INJ_FATAL      75
# FLT_CRW_INJ_UNK        83
# CBN_CRW_INJ_NONE       83
# CBN_CRW_INJ_MINOR      83
# CBN_CRW_INJ_SERIOUS    83
# CBN_CRW_INJ_FATAL      83
# CBN_CRW_INJ_UNK        82
# PAX_INJ_NONE           66
# PAX_INJ_MINOR          82
# PAX_INJ_SERIOUS        80
# PAX_INJ_FATAL          82
# PAX_INJ_UNK            83
# GRND_INJ_NONE          83
# GRND_INJ_MINOR         83
# GRND_INJ_SERIOUS       83
# GRND_INJ_FATAL         83
# GRND_INJ_UNK           82
# dtype: int64

# %% [markdown]
# g.	Clean the dataset and replace the fatal flag NaN with “No”

# %%
#replace error with nan
faa['FATAL_FLAG'].replace('?', np.NaN)

# replace NaN with No
faa_df=faa['FATAL_FLAG'].replace('NaN', 'No')

faa_df
# Out:
# 0     Yes
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#      ...
# 78    NaN
# 79    Yes
# 80    Yes
# 81    Yes
# 82    Yes
# Name: FATAL_FLAG, Length: 83, dtype: object

# %% [markdown]
# h.	Verify if the missing values are replaced.

# %%
faa[['FATAL_FLAG']]
# Out:
#    FATAL_FLAG
# 0         Yes
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 78        NaN
# 79        Yes
# 80        Yes
# 81        Yes
# 82        Yes
#
# [83 rows x 1 columns]

# %% [markdown]
# i.	Remove all the observations where aircraft names (ACFT_MAKE_NAME) are not available

# %%
faa['ACFT_MAKE_NAME'].dropna(inplace=True)
faa['ACFT_MAKE_NAME']
# Out:
# 0              BEECH
# 1               VANS
# 2             CESSNA
# 3            LANCAIR
# 4             CESSNA
#            ...
# 78           AERONCA
# 79    NORTH AMERICAN
# 80          CHAMPION
# 81             BEECH
# 82            CESSNA
# Name: ACFT_MAKE_NAME, Length: 83, dtype: object

# %% [markdown]
# j.	Find the aircraft types and their occurrences in the dataset

# %%
faa.groupby(['ACFT_MAKE_NAME','ACFT_MODEL_NAME']).count().sort_values(by = 'ACFT_MAKE_NAME')
# Out:
#                                         UPDATED  ENTRY_DATE  EVENT_LCL_DATE  \
# ACFT_MAKE_NAME         ACFT_MODEL_NAME
# AERO COMMANDER         500                    1           1               1
# AERONCA                O58B                   1           1               1
# AEROSTAR INTERNATIONAL RX8                    1           1               1
# AIRBUS                 A319                   1           1               1
# BEECH                  33                     1           1               1
#                        35                     3           3               3
#                        36                     3           3               3
#                        55                     1           1               1
#                        T34                    1           1               1
# BELL                   206                    1           1               1
#                        47G                    1           1               1
# BOEING                 747                    1           1               1
#                        737                    2           2               2
# CESSNA                 140                    1           1               1
#                        150                    3           3               3
#                        152                    2           2               2
#                        172                    4           4               4
#                        175                    1           1               1
#                        180                    1           1               1
#                        182                    2           2               2
#                        206                    2           2               2
#                        210                    4           4               4
#                        310                    2           2               2
#                        560                    1           1               1
# CHAMPION               8KCAB                  2           2               2
# CHRISTEN               EAGLE II               1           1               1
# CONSOLIDATED VULTEE    BT15                   1           1               1
# EMBRAER                ERJ190                 1           1               1
# FAIRCHILD              PT19                   1           1               1
# FLIGHT DESIGN          CTLS                   1           1               1
# GLOBE                  GC1B                   1           1               1
# GREAT LAKES            2T1A                   1           1               1
# GRUMMAN                AA1                    1           1               1
# GULFSTREAM             GULFSTREAM200          1           1               1
# HUGHES                 369                    1           1               1
# LANCAIR                235                    1           1               1
#                        IV                     1           1               1
# MAULE                  M4                     1           1               1
# MOONEY                 M20M                   1           1               1
#                        M20K                   2           2               2
#                        M20E                   1           1               1
# NORTH AMERICAN         F51                    1           1               1
# PIPER                  PA20                   1           1               1
#                        PA24                   2           2               2
#                        PA28                   3           3               3
#                        PA31                   1           1               1
#                        PA34                   3           3               3
# PITTS                  S2                     1           1               1
# SAAB                   340                    1           1               1
# SABRELINER             NA265                  1           1               1
# SOCATA                 TB21                   1           1               1
#                        TB9                    1           1               1
# VANS                   RV7                    1           1               1
#
#                                         EVENT_LCL_TIME  LOC_CITY_NAME  \
# ACFT_MAKE_NAME         ACFT_MODEL_NAME
# AERO COMMANDER         500                           1              1
# AERONCA                O58B                          1              1
# AEROSTAR INTERNATIONAL RX8                           1              1
# AIRBUS                 A319                          1              1
# BEECH                  33                            1              1
#                        35                            3              3
#                        36                            3              3
#                        55                            1              1
#                        T34                           1              1
# BELL                   206                           1              1
#                        47G                           1              1
# BOEING                 747                           1              1
#                        737                           2              2
# CESSNA                 140                           1              1
#                        150                           3              3
#                        152                           2              2
#                        172                           4              4
#                        175                           1              1
#                        180                           1              1
#                        182                           2              2
#                        206                           2              2
#                        210                           4              4
#                        310                           2              2
#                        560                           1              1
# CHAMPION               8KCAB                         2              2
# CHRISTEN               EAGLE II                      1              1
# CONSOLIDATED VULTEE    BT15                          1              1
# EMBRAER                ERJ190                        1              1
# FAIRCHILD              PT19                          1              1
# FLIGHT DESIGN          CTLS                          1              1
# GLOBE                  GC1B                          1              1
# GREAT LAKES            2T1A                          1              1
# GRUMMAN                AA1                           1              1
# GULFSTREAM             GULFSTREAM200                 1              1
# HUGHES                 369                           1              1
# LANCAIR                235                           1              1
#                        IV                            1              1
# MAULE                  M4                            1              1
# MOONEY                 M20M                          1              1
#                        M20K                          2              2
#                        M20E                          1              1
# NORTH AMERICAN         F51                           1              1
# PIPER                  PA20                          1              1
#                        PA24                          2              2
#                        PA28                          3              3
#                        PA31                          1              1
#                        PA34                          3              3
# PITTS                  S2                            1              1
# SAAB                   340                           1              1
# SABRELINER             NA265                         1              1
# SOCATA                 TB21                          1              1
#                        TB9                           1              1
# VANS                   RV7                           1              1
#
#                                         LOC_STATE_NAME  LOC_CNTRY_NAME  \
# ACFT_MAKE_NAME         ACFT_MODEL_NAME
# AERO COMMANDER         500                           1               0
# AERONCA                O58B                          1               0
# AEROSTAR INTERNATIONAL RX8                           1               0
# AIRBUS                 A319                          1               0
# BEECH                  33                            1               0
#                        35                            3               0
#                        36                            3               0
#                        55                            1               0
#                        T34                           1               0
# BELL                   206                           1               0
#                        47G                           1               0
# BOEING                 747                           1               0
#                        737                           2               0
# CESSNA                 140                           1               0
#                        150                           3               0
#                        152                           2               0
#                        172                           4               0
#                        175                           1               0
#                        180                           1               0
#                        182                           2               1
#                        206                           2               0
#                        210                           4               0
#                        310                           2               0
#                        560                           1               0
# CHAMPION               8KCAB                         2               0
# CHRISTEN               EAGLE II                      1               0
# CONSOLIDATED VULTEE    BT15                          1               0
# EMBRAER                ERJ190                        1               0
# FAIRCHILD              PT19                          1               0
# FLIGHT DESIGN          CTLS                          1               0
# GLOBE                  GC1B                          1               0
# GREAT LAKES            2T1A                          1               0
# GRUMMAN                AA1                           1               0
# GULFSTREAM             GULFSTREAM200                 1               0
# HUGHES                 369                           1               0
# LANCAIR                235                           1               0
#                        IV                            1               0
# MAULE                  M4                            1               0
# MOONEY                 M20M                          1               0
#                        M20K                          2               0
#                        M20E                          1               0
# NORTH AMERICAN         F51                           1               0
# PIPER                  PA20                          1               0
#                        PA24                          2               0
#                        PA28                          3               1
#                        PA31                          1               0
#                        PA34                          3               0
# PITTS                  S2                            1               0
# SAAB                   340                           1               0
# SABRELINER             NA265                         1               0
# SOCATA                 TB21                          1               0
#                        TB9                           1               0
# VANS                   RV7                           1               0
#
#                                         RMK_TEXT  EVENT_TYPE_DESC  FSDO_DESC  \
# ACFT_MAKE_NAME         ACFT_MODEL_NAME
# AERO COMMANDER         500                     1                1          1
# AERONCA                O58B                    1                1          1
# AEROSTAR INTERNATIONAL RX8                     1                1          1
# AIRBUS                 A319                    1                1          1
# BEECH                  33                      1                1          1
#                        35                      3                3          3
#                        36                      3                3          3
#                        55                      1                1          1
#                        T34                     1                1          1
# BELL                   206                     1                1          1
#                        47G                     1                1          1
# BOEING                 747                     1                1          1
#                        737                     2                2          2
# CESSNA                 140                     1                1          1
#                        150                     3                3          3
#                        152                     2                2          2
#                        172                     4                4          4
#                        175                     1                1          1
#                        180                     1                1          1
#                        182                     2                2          1
#                        206                     2                2          2
#                        210                     4                4          4
#                        310                     2                2          2
#                        560                     1                1          1
# CHAMPION               8KCAB                   2                2          2
# CHRISTEN               EAGLE II                1                1          1
# CONSOLIDATED VULTEE    BT15                    1                1          1
# EMBRAER                ERJ190                  1                1          1
# FAIRCHILD              PT19                    1                1          1
# FLIGHT DESIGN          CTLS                    1                1          1
# GLOBE                  GC1B                    1                1          1
# GREAT LAKES            2T1A                    1                1          1
# GRUMMAN                AA1                     1                1          1
# GULFSTREAM             GULFSTREAM200           1                1          1
# HUGHES                 369                     1                1          1
# LANCAIR                235                     1                1          1
#                        IV                      1                1          1
# MAULE                  M4                      1                1          1
# MOONEY                 M20M                    1                1          1
#                        M20K                    2                2          2
#                        M20E                    1                1          1
# NORTH AMERICAN         F51                     1                1          1
# PIPER                  PA20                    1                1          1
#                        PA24                    2                2          2
#                        PA28                    3                3          2
#                        PA31                    1                1          1
#                        PA34                    3                3          3
# PITTS                  S2                      1                1          1
# SAAB                   340                     1                1          1
# SABRELINER             NA265                   1                1          1
# SOCATA                 TB21                    1                1          1
#                        TB9                     1                1          1
# VANS                   RV7                     1                1          1
#
#                                         ...  PAX_INJ_NONE  PAX_INJ_MINOR  \
# ACFT_MAKE_NAME         ACFT_MODEL_NAME  ...
# AERO COMMANDER         500              ...             0              0
# AERONCA                O58B             ...             0              0
# AEROSTAR INTERNATIONAL RX8              ...             1              0
# AIRBUS                 A319             ...             0              0
# BEECH                  33               ...             0              0
#                        35               ...             0              0
#                        36               ...             1              0
#                        55               ...             1              0
#                        T34              ...             0              0
# BELL                   206              ...             0              0
#                        47G              ...             0              0
# BOEING                 747              ...             0              0
#                        737              ...             0              0
# CESSNA                 140              ...             1              0
#                        150              ...             1              0
#                        152              ...             0              0
#                        172              ...             0              1
#                        175              ...             1              0
#                        180              ...             1              0
#                        182              ...             0              0
#                        206              ...             0              0
#                        210              ...             3              0
#                        310              ...             0              0
#                        560              ...             1              0
# CHAMPION               8KCAB            ...             1              0
# CHRISTEN               EAGLE II         ...             0              0
# CONSOLIDATED VULTEE    BT15             ...             0              0
# EMBRAER                ERJ190           ...             0              0
# FAIRCHILD              PT19             ...             0              0
# FLIGHT DESIGN          CTLS             ...             0              0
# GLOBE                  GC1B             ...             0              0
# GREAT LAKES            2T1A             ...             0              0
# GRUMMAN                AA1              ...             0              0
# GULFSTREAM             GULFSTREAM200    ...             1              0
# HUGHES                 369              ...             0              0
# LANCAIR                235              ...             0              0
#                        IV               ...             0              0
# MAULE                  M4               ...             0              0
# MOONEY                 M20M             ...             0              0
#                        M20K             ...             1              0
#                        M20E             ...             0              0
# NORTH AMERICAN         F51              ...             0              0
# PIPER                  PA20             ...             0              0
#                        PA24             ...             0              0
#                        PA28             ...             0              0
#                        PA31             ...             0              0
#                        PA34             ...             1              0
# PITTS                  S2               ...             0              0
# SAAB                   340              ...             0              0
# SABRELINER             NA265            ...             0              0
# SOCATA                 TB21             ...             0              0
#                        TB9              ...             0              0
# VANS                   RV7              ...             0              0
#
#                                         PAX_INJ_SERIOUS  PAX_INJ_FATAL  \
# ACFT_MAKE_NAME         ACFT_MODEL_NAME
# AERO COMMANDER         500                            0              0
# AERONCA                O58B                           0              0
# AEROSTAR INTERNATIONAL RX8                            1              0
# AIRBUS                 A319                           1              0
# BEECH                  33                             0              0
#                        35                             0              0
#                        36                             0              0
#                        55                             0              0
#                        T34                            0              0
# BELL                   206                            0              0
#                        47G                            0              0
# BOEING                 747                            0              0
#                        737                            0              0
# CESSNA                 140                            0              0
#                        150                            0              0
#                        152                            0              0
#                        172                            0              0
#                        175                            0              0
#                        180                            0              0
#                        182                            0              0
#                        206                            0              0
#                        210                            1              0
#                        310                            0              0
#                        560                            0              0
# CHAMPION               8KCAB                          0              0
# CHRISTEN               EAGLE II                       0              0
# CONSOLIDATED VULTEE    BT15                           0              0
# EMBRAER                ERJ190                         0              0
# FAIRCHILD              PT19                           0              0
# FLIGHT DESIGN          CTLS                           0              0
# GLOBE                  GC1B                           0              0
# GREAT LAKES            2T1A                           0              0
# GRUMMAN                AA1                            0              0
# GULFSTREAM             GULFSTREAM200                  0              0
# HUGHES                 369                            0              0
# LANCAIR                235                            0              0
#                        IV                             0              0
# MAULE                  M4                             0              0
# MOONEY                 M20M                           0              0
#                        M20K                           0              0
#                        M20E                           0              0
# NORTH AMERICAN         F51                            0              0
# PIPER                  PA20                           0              0
#                        PA24                           0              0
#                        PA28                           0              1
#                        PA31                           0              0
#                        PA34                           0              0
# PITTS                  S2                             0              0
# SAAB                   340                            0              0
# SABRELINER             NA265                          0              0
# SOCATA                 TB21                           0              0
#                        TB9                            0              0
# VANS                   RV7                            0              0
#
#                                         PAX_INJ_UNK  GRND_INJ_NONE  \
# ACFT_MAKE_NAME         ACFT_MODEL_NAME
# AERO COMMANDER         500                        0              0
# AERONCA                O58B                       0              0
# AEROSTAR INTERNATIONAL RX8                        0              0
# AIRBUS                 A319                       0              0
# BEECH                  33                         0              0
#                        35                         0              0
#                        36                         0              0
#                        55                         0              0
#                        T34                        0              0
# BELL                   206                        0              0
#                        47G                        0              0
# BOEING                 747                        0              0
#                        737                        0              0
# CESSNA                 140                        0              0
#                        150                        0              0
#                        152                        0              0
#                        172                        0              0
#                        175                        0              0
#                        180                        0              0
#                        182                        0              0
#                        206                        0              0
#                        210                        0              0
#                        310                        0              0
#                        560                        0              0
# CHAMPION               8KCAB                      0              0
# CHRISTEN               EAGLE II                   0              0
# CONSOLIDATED VULTEE    BT15                       0              0
# EMBRAER                ERJ190                     0              0
# FAIRCHILD              PT19                       0              0
# FLIGHT DESIGN          CTLS                       0              0
# GLOBE                  GC1B                       0              0
# GREAT LAKES            2T1A                       0              0
# GRUMMAN                AA1                        0              0
# GULFSTREAM             GULFSTREAM200              0              0
# HUGHES                 369                        0              0
# LANCAIR                235                        0              0
#                        IV                         0              0
# MAULE                  M4                         0              0
# MOONEY                 M20M                       0              0
#                        M20K                       0              0
#                        M20E                       0              0
# NORTH AMERICAN         F51                        0              0
# PIPER                  PA20                       0              0
#                        PA24                       0              0
#                        PA28                       0              0
#                        PA31                       0              0
#                        PA34                       0              0
# PITTS                  S2                         0              0
# SAAB                   340                        0              0
# SABRELINER             NA265                      0              0
# SOCATA                 TB21                       0              0
#                        TB9                        0              0
# VANS                   RV7                        0              0
#
#                                         GRND_INJ_MINOR  GRND_INJ_SERIOUS  \
# ACFT_MAKE_NAME         ACFT_MODEL_NAME
# AERO COMMANDER         500                           0                 0
# AERONCA                O58B                          0                 0
# AEROSTAR INTERNATIONAL RX8                           0                 0
# AIRBUS                 A319                          0                 0
# BEECH                  33                            0                 0
#                        35                            0                 0
#                        36                            0                 0
#                        55                            0                 0
#                        T34                           0                 0
# BELL                   206                           0                 0
#                        47G                           0                 0
# BOEING                 747                           0                 0
#                        737                           0                 0
# CESSNA                 140                           0                 0
#                        150                           0                 0
#                        152                           0                 0
#                        172                           0                 0
#                        175                           0                 0
#                        180                           0                 0
#                        182                           0                 0
#                        206                           0                 0
#                        210                           0                 0
#                        310                           0                 0
#                        560                           0                 0
# CHAMPION               8KCAB                         0                 0
# CHRISTEN               EAGLE II                      0                 0
# CONSOLIDATED VULTEE    BT15                          0                 0
# EMBRAER                ERJ190                        0                 0
# FAIRCHILD              PT19                          0                 0
# FLIGHT DESIGN          CTLS                          0                 0
# GLOBE                  GC1B                          0                 0
# GREAT LAKES            2T1A                          0                 0
# GRUMMAN                AA1                           0                 0
# GULFSTREAM             GULFSTREAM200                 0                 0
# HUGHES                 369                           0                 0
# LANCAIR                235                           0                 0
#                        IV                            0                 0
# MAULE                  M4                            0                 0
# MOONEY                 M20M                          0                 0
#                        M20K                          0                 0
#                        M20E                          0                 0
# NORTH AMERICAN         F51                           0                 0
# PIPER                  PA20                          0                 0
#                        PA24                          0                 0
#                        PA28                          0                 0
#                        PA31                          0                 0
#                        PA34                          0                 0
# PITTS                  S2                            0                 0
# SAAB                   340                           0                 0
# SABRELINER             NA265                         0                 0
# SOCATA                 TB21                          0                 0
#                        TB9                           0                 0
# VANS                   RV7                           0                 0
#
#                                         GRND_INJ_FATAL  GRND_INJ_UNK
# ACFT_MAKE_NAME         ACFT_MODEL_NAME
# AERO COMMANDER         500                           0             0
# AERONCA                O58B                          0             0
# AEROSTAR INTERNATIONAL RX8                           0             0
# AIRBUS                 A319                          0             0
# BEECH                  33                            0             0
#                        35                            0             0
#                        36                            0             0
#                        55                            0             0
#                        T34                           0             0
# BELL                   206                           0             0
#                        47G                           0             0
# BOEING                 747                           0             0
#                        737                           0             0
# CESSNA                 140                           0             0
#                        150                           0             0
#                        152                           0             0
#                        172                           0             0
#                        175                           0             0
#                        180                           0             0
#                        182                           0             0
#                        206                           0             0
#                        210                           0             0
#                        310                           0             0
#                        560                           0             0
# CHAMPION               8KCAB                         0             0
# CHRISTEN               EAGLE II                      0             0
# CONSOLIDATED VULTEE    BT15                          0             0
# EMBRAER                ERJ190                        0             0
# FAIRCHILD              PT19                          0             0
# FLIGHT DESIGN          CTLS                          0             0
# GLOBE                  GC1B                          0             0
# GREAT LAKES            2T1A                          0             0
# GRUMMAN                AA1                           0             0
# GULFSTREAM             GULFSTREAM200                 0             1
# HUGHES                 369                           0             0
# LANCAIR                235                           0             0
#                        IV                            0             0
# MAULE                  M4                            0             0
# MOONEY                 M20M                          0             0
#                        M20K                          0             0
#                        M20E                          0             0
# NORTH AMERICAN         F51                           0             0
# PIPER                  PA20                          0             0
#                        PA24                          0             0
#                        PA28                          0             0
#                        PA31                          0             0
#                        PA34                          0             0
# PITTS                  S2                            0             0
# SAAB                   340                           0             0
# SABRELINER             NA265                         0             0
# SOCATA                 TB21                          0             0
#                        TB9                           0             0
# VANS                   RV7                           0             0
#
# [53 rows x 40 columns]

# %% [markdown]
# k.	Display the observations where fatal flag is “Yes”.

# %%
faa[(faa['FATAL_FLAG']=='Yes')]
# Out:
#    UPDATED ENTRY_DATE EVENT_LCL_DATE EVENT_LCL_TIME LOC_CITY_NAME  \
# 0       No  19-FEB-16      19-FEB-16      00:45:00Z    MARSHVILLE
# 22      No  17-FEB-16      16-FEB-16      20:52:00Z       BUCKEYE
# 53      No  12-FEB-16      11-FEB-16      11:32:00Z        DESTIN
# 55      No  11-FEB-16      11-FEB-16      00:17:00Z        TULARE
# 79      No  08-FEB-16      05-FEB-16      11:17:00Z      MARICOPA
# 80      No  08-FEB-16      05-FEB-16      23:02:00Z     SAN PEDRO
# 81      No  08-FEB-16      05-FEB-16      23:02:00Z     SAN PEDRO
# 82     Yes  02-FEB-16      02-FEB-16      01:52:00Z        MOBILE
#
#     LOC_STATE_NAME LOC_CNTRY_NAME  \
# 0   North Carolina            NaN
# 22         Arizona            NaN
# 53         Florida  United States
# 55      California            NaN
# 79         Arizona            NaN
# 80      California            NaN
# 81      California            NaN
# 82         Alabama            NaN
#
#                                              RMK_TEXT EVENT_TYPE_DESC  \
# 0   AIRCRAFT CRASHED INTO TREES, THE 1 PERSON ON B...        Accident
# 22  AIRCRAFT, LIGHT SPORT EVOLUTION REVO,  ON TAKE...        Accident
# 53  AIRCRAFT CRASHED UNDER UNKNOWN CIRCUMSTANCES. ...        Accident
# 55  AIRCRAFT CRASHED UNDER UNKNOWN CIRCUMSTANCES A...        Accident
# 79  AIRCRAFT CRASHED UNDER UNKNOWN CIRCUMSTANCES, ...        Accident
# 80  N9872R, BEECH M35 AIRCRAFT, AND N5057G, BELLAN...        Accident
# 81  N9872R, BEECH M35 AIRCRAFT, AND N5057G, BELLAN...        Accident
# 82  N784CP AIRCRAFT CRASHED INTO A WOODED AREA NEA...        Accident
#
#                  FSDO_DESC  ... PAX_INJ_NONE PAX_INJ_MINOR PAX_INJ_SERIOUS  \
# 0    FAA Charlotte FSDO-68  ...          NaN           NaN             NaN
# 22  FAA Scottsdale FSDO-07  ...          NaN           NaN             NaN
# 53                     NaN  ...          NaN           NaN             NaN
# 55      FAA Fresno FSDO-17  ...          NaN           NaN             NaN
# 79  FAA Scottsdale FSDO-07  ...          NaN           NaN             NaN
# 80  FAA Long Beach FSDO-05  ...          NaN           NaN             NaN
# 81  FAA Long Beach FSDO-05  ...          NaN           NaN             NaN
# 82  FAA Birmingham FSDO-09  ...          NaN           NaN             NaN
#
#    PAX_INJ_FATAL PAX_INJ_UNK  GRND_INJ_NONE GRND_INJ_MINOR GRND_INJ_SERIOUS  \
# 0            NaN         NaN            NaN            NaN              NaN
# 22           NaN         NaN            NaN            NaN              NaN
# 53           1.0         NaN            NaN            NaN              NaN
# 55           NaN         NaN            NaN            NaN              NaN
# 79           NaN         NaN            NaN            NaN              NaN
# 80           NaN         NaN            NaN            NaN              NaN
# 81           NaN         NaN            NaN            NaN              NaN
# 82           NaN         NaN            NaN            NaN              NaN
#
#    GRND_INJ_FATAL  GRND_INJ_UNK
# 0             NaN           NaN
# 22            NaN           NaN
# 53            NaN           NaN
# 55            NaN           NaN
# 79            NaN           NaN
# 80            NaN           NaN
# 81            NaN           NaN
# 82            NaN           NaN
#
# [8 rows x 42 columns]

# %%
faa.query("`FATAL_FLAG` == 'Yes'")
# Out:
#    UPDATED ENTRY_DATE EVENT_LCL_DATE EVENT_LCL_TIME LOC_CITY_NAME  \
# 0       No  19-FEB-16      19-FEB-16      00:45:00Z    MARSHVILLE
# 22      No  17-FEB-16      16-FEB-16      20:52:00Z       BUCKEYE
# 53      No  12-FEB-16      11-FEB-16      11:32:00Z        DESTIN
# 55      No  11-FEB-16      11-FEB-16      00:17:00Z        TULARE
# 79      No  08-FEB-16      05-FEB-16      11:17:00Z      MARICOPA
# 80      No  08-FEB-16      05-FEB-16      23:02:00Z     SAN PEDRO
# 81      No  08-FEB-16      05-FEB-16      23:02:00Z     SAN PEDRO
# 82     Yes  02-FEB-16      02-FEB-16      01:52:00Z        MOBILE
#
#     LOC_STATE_NAME LOC_CNTRY_NAME  \
# 0   North Carolina            NaN
# 22         Arizona            NaN
# 53         Florida  United States
# 55      California            NaN
# 79         Arizona            NaN
# 80      California            NaN
# 81      California            NaN
# 82         Alabama            NaN
#
#                                              RMK_TEXT EVENT_TYPE_DESC  \
# 0   AIRCRAFT CRASHED INTO TREES, THE 1 PERSON ON B...        Accident
# 22  AIRCRAFT, LIGHT SPORT EVOLUTION REVO,  ON TAKE...        Accident
# 53  AIRCRAFT CRASHED UNDER UNKNOWN CIRCUMSTANCES. ...        Accident
# 55  AIRCRAFT CRASHED UNDER UNKNOWN CIRCUMSTANCES A...        Accident
# 79  AIRCRAFT CRASHED UNDER UNKNOWN CIRCUMSTANCES, ...        Accident
# 80  N9872R, BEECH M35 AIRCRAFT, AND N5057G, BELLAN...        Accident
# 81  N9872R, BEECH M35 AIRCRAFT, AND N5057G, BELLAN...        Accident
# 82  N784CP AIRCRAFT CRASHED INTO A WOODED AREA NEA...        Accident
#
#                  FSDO_DESC  ... PAX_INJ_NONE PAX_INJ_MINOR PAX_INJ_SERIOUS  \
# 0    FAA Charlotte FSDO-68  ...          NaN           NaN             NaN
# 22  FAA Scottsdale FSDO-07  ...          NaN           NaN             NaN
# 53                     NaN  ...          NaN           NaN             NaN
# 55      FAA Fresno FSDO-17  ...          NaN           NaN             NaN
# 79  FAA Scottsdale FSDO-07  ...          NaN           NaN             NaN
# 80  FAA Long Beach FSDO-05  ...          NaN           NaN             NaN
# 81  FAA Long Beach FSDO-05  ...          NaN           NaN             NaN
# 82  FAA Birmingham FSDO-09  ...          NaN           NaN             NaN
#
#    PAX_INJ_FATAL PAX_INJ_UNK  GRND_INJ_NONE GRND_INJ_MINOR GRND_INJ_SERIOUS  \
# 0            NaN         NaN            NaN            NaN              NaN
# 22           NaN         NaN            NaN            NaN              NaN
# 53           1.0         NaN            NaN            NaN              NaN
# 55           NaN         NaN            NaN            NaN              NaN
# 79           NaN         NaN            NaN            NaN              NaN
# 80           NaN         NaN            NaN            NaN              NaN
# 81           NaN         NaN            NaN            NaN              NaN
# 82           NaN         NaN            NaN            NaN              NaN
#
#    GRND_INJ_FATAL  GRND_INJ_UNK
# 0             NaN           NaN
# 22            NaN           NaN
# 53            NaN           NaN
# 55            NaN           NaN
# 79            NaN           NaN
# 80            NaN           NaN
# 81            NaN           NaN
# 82            NaN           NaN
#
# [8 rows x 42 columns]

# %% [markdown]
# l.	Show the accidents with fatality.

# %%
faa[(faa['EVENT_TYPE_DESC']=='Accident')&(faa['FATAL_FLAG']=='Yes')]
# Out:
#    UPDATED ENTRY_DATE EVENT_LCL_DATE EVENT_LCL_TIME LOC_CITY_NAME  \
# 0       No  19-FEB-16      19-FEB-16      00:45:00Z    MARSHVILLE
# 22      No  17-FEB-16      16-FEB-16      20:52:00Z       BUCKEYE
# 53      No  12-FEB-16      11-FEB-16      11:32:00Z        DESTIN
# 55      No  11-FEB-16      11-FEB-16      00:17:00Z        TULARE
# 79      No  08-FEB-16      05-FEB-16      11:17:00Z      MARICOPA
# 80      No  08-FEB-16      05-FEB-16      23:02:00Z     SAN PEDRO
# 81      No  08-FEB-16      05-FEB-16      23:02:00Z     SAN PEDRO
# 82     Yes  02-FEB-16      02-FEB-16      01:52:00Z        MOBILE
#
#     LOC_STATE_NAME LOC_CNTRY_NAME  \
# 0   North Carolina            NaN
# 22         Arizona            NaN
# 53         Florida  United States
# 55      California            NaN
# 79         Arizona            NaN
# 80      California            NaN
# 81      California            NaN
# 82         Alabama            NaN
#
#                                              RMK_TEXT EVENT_TYPE_DESC  \
# 0   AIRCRAFT CRASHED INTO TREES, THE 1 PERSON ON B...        Accident
# 22  AIRCRAFT, LIGHT SPORT EVOLUTION REVO,  ON TAKE...        Accident
# 53  AIRCRAFT CRASHED UNDER UNKNOWN CIRCUMSTANCES. ...        Accident
# 55  AIRCRAFT CRASHED UNDER UNKNOWN CIRCUMSTANCES A...        Accident
# 79  AIRCRAFT CRASHED UNDER UNKNOWN CIRCUMSTANCES, ...        Accident
# 80  N9872R, BEECH M35 AIRCRAFT, AND N5057G, BELLAN...        Accident
# 81  N9872R, BEECH M35 AIRCRAFT, AND N5057G, BELLAN...        Accident
# 82  N784CP AIRCRAFT CRASHED INTO A WOODED AREA NEA...        Accident
#
#                  FSDO_DESC  ... PAX_INJ_NONE PAX_INJ_MINOR PAX_INJ_SERIOUS  \
# 0    FAA Charlotte FSDO-68  ...          NaN           NaN             NaN
# 22  FAA Scottsdale FSDO-07  ...          NaN           NaN             NaN
# 53                     NaN  ...          NaN           NaN             NaN
# 55      FAA Fresno FSDO-17  ...          NaN           NaN             NaN
# 79  FAA Scottsdale FSDO-07  ...          NaN           NaN             NaN
# 80  FAA Long Beach FSDO-05  ...          NaN           NaN             NaN
# 81  FAA Long Beach FSDO-05  ...          NaN           NaN             NaN
# 82  FAA Birmingham FSDO-09  ...          NaN           NaN             NaN
#
#    PAX_INJ_FATAL PAX_INJ_UNK  GRND_INJ_NONE GRND_INJ_MINOR GRND_INJ_SERIOUS  \
# 0            NaN         NaN            NaN            NaN              NaN
# 22           NaN         NaN            NaN            NaN              NaN
# 53           1.0         NaN            NaN            NaN              NaN
# 55           NaN         NaN            NaN            NaN              NaN
# 79           NaN         NaN            NaN            NaN              NaN
# 80           NaN         NaN            NaN            NaN              NaN
# 81           NaN         NaN            NaN            NaN              NaN
# 82           NaN         NaN            NaN            NaN              NaN
#
#    GRND_INJ_FATAL  GRND_INJ_UNK
# 0             NaN           NaN
# 22            NaN           NaN
# 53            NaN           NaN
# 55            NaN           NaN
# 79            NaN           NaN
# 80            NaN           NaN
# 81            NaN           NaN
# 82            NaN           NaN
#
# [8 rows x 42 columns]
